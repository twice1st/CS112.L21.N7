# %% [markdown]
# <a href="https://colab.research.google.com/github/twice1st/CS112.L21.N7/blob/branch_1/Assignment_4/Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BÀI 1: SỬA HÀNG RÀO**

# %% [markdown]
# 1. **Abstraction**: Cho hai mảng số dương hangrao và gothua, tìm và cộng các số trong gothua vào các số trong hangrao sao cho số bé nhất của hangrao là lớn nhất. (*Note: vị trí các miếng gỗ trong gothua cộng vào hangrao là không giảm*).
# 2. **Recognition**:
# 3. **Algorithm designed**: (Lưu đồ thuật toán)
# 4. **Alogrithm Complexity**:
# 5. **Programming**:

# %% [markdown]
# #**BÀI 2: FRACTION**

# %% [markdown]
# 1. **Abstraction**: Cho 2 phân số a/b và c/d, tìm số bước biến đổi bằng cách tăng a và b lên 1 rồi giản ước chúng sao cho phân đầu bằng phân số sau.
# 2. **Recognition**: sử dụng các kỹ thuật cơ bản về biến, vòng lặp, và hàm có sẵn để thực hiện.
# 3. **Algorithm designed**: (Lưu đồ thuật toán)
# 4. **Alogrithm Complexity**: O(max(c-a, d-b))

# %% [markdown]
# ![image.png](data:image/png;base64,...)
